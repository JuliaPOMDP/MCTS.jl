# %%
using MCTS
using POMDPModels # for GridWorld

# %% [markdown]
# # Choosing Actions For Progressive Widening
#
# Often, when we are using double progressive widening, we want to consider certain actions first. We can accomplish this by defining an `ActionGenerator` and implementing a new method of `next_action`.
#
# ## Trivial Example
#
# First, let's begin with a trivial example: suppose that we only want to consider "up" actions in the grid world problem. We define the `OnlyUp` action generator to accomplish this.

# %%
type OnlyUp <: ActionGenerator end

function MCTS.next_action(gen::OnlyUp, mdp::GridWorld, s, snode)
    return GridWorldAction(:up)
end

# %% [markdown]
# Now we can use this in the DPW Solver:

# %%
mdp = GridWorld()
solver = DPWSolver(action_generator=OnlyUp(), n_iterations=10)
policy = solve(solver, mdp)
action(policy, GridWorldState(1,1))
# Out:
# POMDPModels.GridWorldAction(:up)

# %% [markdown]
# When the tree below is examined, we see that the planner only considers "up" actions.

# %%
TreeVisualizer(policy, GridWorldState(1,1))
# Out:
# MCTS.TreeVisualizer{MCTS.DPWPolicy{POMDPModels.GridWorldState,POMDPModels.GridWorldAction,Void}}(MCTS.DPWPolicy{POMDPModels.GridWorldState,POMDPModels.GridWorldAction,Void}(MCTS.DPWSolver(10,1.0,10,10.0,0.5,10.0,0.5,MersenneTwister(UInt32[0x00000000],Base.dSFMT.DSFMT_state(Int32[40050240,1073556905,73498706,1073647826,-1089444967,1072865807,-977052619,1072879190,-45002352,1072985674  …  16662824,1073697506,-1449805205,1073181468,-372400594,-464573168,1328968160,-848168375,382,0]),[1.82365,1.91036,1.16457,1.17733,1.27888,1.20348,1.0423,1.06827,1.36183,1.97322  …  1.63895,1.12019,1.62543,1.69274,1.87687,1.12372,1.40174,1.18107,1.95774,1.4656],174),POMDPToolbox.RandomSolver(MersenneTwister(UInt32[0x00000000],Base.dSFMT.DSFMT_state(Int32[40050240,1073556905,73498706,1073647826,-1089444967,1072865807,-977052619,1072879190,-45002352,1072985674  …  16662824,1073697506,-1449805205,1073181468,-372400594,-464573168,1328968160,-848168375,382,0]),[1.82365,1.91036,1.16457,1.17733,1.27888,1.20348,1.0423,1.06827,1.36183,1.97322  …  1.63895,1.12019,1.62543,1.69274,1.87687,1.12372,1.40174,1.18107,1.95774,1.4656],174)),nothing,OnlyUp()),POMDPModels.GridWorld(10,10,POMDPModels.GridWorldState[POMDPModels.GridWorldState(4,3,false),POMDPModels.GridWorldState(4,6,false),POMDPModels.GridWorldState(9,3,false),POMDPModels.GridWorldState(8,8,false)],[-10.0,-5.0,10.0,3.0],0.0,0.7,Set(POMDPModels.GridWorldState[POMDPModels.GridWorldState(8,8,false),POMDPModels.GridWorldState(9,3,false)]),0.95,[0.0,0.0]),Dict(POMDPModels.GridWorldState(3,2,false)=>MCTS.DPWStateNode{POMDPModels.GridWorldState,POMDPModels.GridWorldAction}(Dict{POMDPModels.GridWorldAction,MCTS.DPWStateActionNode{POMDPModels.GridWorldState}}(),1),POMDPModels.GridWorldState(1,3,false)=>MCTS.DPWStateNode{POMDPModels.GridWorldState,POMDPModels.GridWorldAction}(Dict(POMDPModels.GridWorldAction(:up)=>MCTS.DPWStateActionNode{POMDPModels.GridWorldState}(Dict(POMDPModels.GridWorldState(1,2,false)=>MCTS.StateActionStateNode(1,0.0),POMDPModels.GridWorldState(1,4,false)=>MCTS.StateActionStateNode(3,0.0),POMDPModels.GridWorldState(2,3,false)=>MCTS.StateActionStateNode(1,0.0)),5,0.0)),6),POMDPModels.GridWorldState(2,2,false)=>MCTS.DPWStateNode{POMDPModels.GridWorldState,POMDPModels.GridWorldAction}(Dict(POMDPModels.GridWorldAction(:up)=>MCTS.DPWStateActionNode{POMDPModels.GridWorldState}(Dict(POMDPModels.GridWorldState(3,2,false)=>MCTS.StateActionStateNode(1,0.0)),1,0.0)),2),POMDPModels.GridWorldState(1,1,false)=>MCTS.DPWStateNode{POMDPModels.GridWorldState,POMDPModels.GridWorldAction}(Dict(POMDPModels.GridWorldAction(:up)=>MCTS.DPWStateActionNode{POMDPModels.GridWorldState}(Dict(POMDPModels.GridWorldState(2,1,false)=>MCTS.StateActionStateNode(3,0.0),POMDPModels.GridWorldState(1,2,false)=>MCTS.StateActionStateNode(6,0.0)),9,0.0)),10),POMDPModels.GridWorldState(1,6,false)=>MCTS.DPWStateNode{POMDPModels.GridWorldState,POMDPModels.GridWorldAction}(Dict{POMDPModels.GridWorldAction,MCTS.DPWStateActionNode{POMDPModels.GridWorldState}}(),1),POMDPModels.GridWorldState(1,5,false)=>MCTS.DPWStateNode{POMDPModels.GridWorldState,POMDPModels.GridWorldAction}(Dict(POMDPModels.GridWorldAction(:up)=>MCTS.DPWStateActionNode{POMDPModels.GridWorldState}(Dict(POMDPModels.GridWorldState(1,6,false)=>MCTS.StateActionStateNode(1,0.0)),1,0.0)),2),POMDPModels.GridWorldState(2,1,false)=>MCTS.DPWStateNode{POMDPModels.GridWorldState,POMDPModels.GridWorldAction}(Dict(POMDPModels.GridWorldAction(:up)=>MCTS.DPWStateActionNode{POMDPModels.GridWorldState}(Dict(POMDPModels.GridWorldState(2,2,false)=>MCTS.StateActionStateNode(2,0.0)),2,0.0)),3),POMDPModels.GridWorldState(1,2,false)=>MCTS.DPWStateNode{POMDPModels.GridWorldState,POMDPModels.GridWorldAction}(Dict(POMDPModels.GridWorldAction(:up)=>MCTS.DPWStateActionNode{POMDPModels.GridWorldState}(Dict(POMDPModels.GridWorldState(1,3,false)=>MCTS.StateActionStateNode(6,0.0)),6,0.0)),7),POMDPModels.GridWorldState(1,4,false)=>MCTS.DPWStateNode{POMDPModels.GridWorldState,POMDPModels.GridWorldAction} ...

# %% [markdown]
# ## Considering previously explored actions
#
# Considering only one action when solving a problem as above is usually a terrible idea. More often, we would like to consider some important action first, and then other actions. The following example considers a special "priority" action first, and then subsequently selects random actions. To accomplish this, `next_action` has to look at the node in the MCTS tree to check if the priority action has already been considered.

# %%
type PriorityAct <: ActionGenerator
    priority
    rng::AbstractRNG
end

function MCTS.next_action(gen::PriorityAct, mdp::GridWorld, s, snode::DPWStateNode)
    if haskey(snode.A, gen.priority) # the priority action is already there
        return rand(gen.rng, actions(mdp, s)) # add a random action
    else
        return gen.priority
    end
end

# %% [markdown]
# We can test this out, setting the priority action to "move right", as follows:

# %%
right_priority = PriorityAct(GridWorldAction(:right), Base.GLOBAL_RNG)
mdp = GridWorld()
solver = DPWSolver(action_generator=right_priority, n_iterations=5)
policy = solve(solver, mdp)
action(policy, GridWorldState(1,1))
# Out:
# POMDPModels.GridWorldAction(:up)

# %% [markdown]
# When we examine the tree below, we see that the "move right" priority action is always considered, but in nodes that have been visited several times, other actions are considered.

# %%
TreeVisualizer(policy, GridWorldState(1,1))
# Out:
# MCTS.TreeVisualizer{MCTS.DPWPolicy{POMDPModels.GridWorldState,POMDPModels.GridWorldAction,Void}}(MCTS.DPWPolicy{POMDPModels.GridWorldState,POMDPModels.GridWorldAction,Void}(MCTS.DPWSolver(10,1.0,5,10.0,0.5,10.0,0.5,MersenneTwister(UInt32[0x00000000],Base.dSFMT.DSFMT_state(Int32[40050240,1073556905,73498706,1073647826,-1089444967,1072865807,-977052619,1072879190,-45002352,1072985674  …  16662824,1073697506,-1449805205,1073181468,-372400594,-464573168,1328968160,-848168375,382,0]),[1.82365,1.91036,1.16457,1.17733,1.27888,1.20348,1.0423,1.06827,1.36183,1.97322  …  1.63895,1.12019,1.62543,1.69274,1.87687,1.12372,1.40174,1.18107,1.95774,1.4656],83),POMDPToolbox.RandomSolver(MersenneTwister(UInt32[0x00000000],Base.dSFMT.DSFMT_state(Int32[40050240,1073556905,73498706,1073647826,-1089444967,1072865807,-977052619,1072879190,-45002352,1072985674  …  16662824,1073697506,-1449805205,1073181468,-372400594,-464573168,1328968160,-848168375,382,0]),[1.82365,1.91036,1.16457,1.17733,1.27888,1.20348,1.0423,1.06827,1.36183,1.97322  …  1.63895,1.12019,1.62543,1.69274,1.87687,1.12372,1.40174,1.18107,1.95774,1.4656],83)),nothing,PriorityAct(POMDPModels.GridWorldAction(:right),MersenneTwister(UInt32[0xa0300338,0x4947ea13,0xd5556ee9,0x07d95055],Base.dSFMT.DSFMT_state(Int32[-1957163641,1073324014,136976459,1073049281,-1617490750,1073110329,-1651982133,1072848303,-1299010870,1073653885  …  933762220,1073278291,-804055630,1072907997,1084732675,1997254165,760081967,-994329285,382,0]),[1.60155,1.33954,1.39776,1.14787,1.91614,1.96434,1.2303,1.5736,1.11058,1.2299  …  1.54141,1.20808,1.38706,1.97903,1.41625,1.62017,1.15975,1.64752,1.55794,1.2048],39))),POMDPModels.GridWorld(10,10,POMDPModels.GridWorldState[POMDPModels.GridWorldState(4,3,false),POMDPModels.GridWorldState(4,6,false),POMDPModels.GridWorldState(9,3,false),POMDPModels.GridWorldState(8,8,false)],[-10.0,-5.0,10.0,3.0],0.0,0.7,Set(POMDPModels.GridWorldState[POMDPModels.GridWorldState(8,8,false),POMDPModels.GridWorldState(9,3,false)]),0.95,[0.0,0.0]),Dict(POMDPModels.GridWorldState(2,2,false)=>MCTS.DPWStateNode{POMDPModels.GridWorldState,POMDPModels.GridWorldAction}(Dict{POMDPModels.GridWorldAction,MCTS.DPWStateActionNode{POMDPModels.GridWorldState}}(),1),POMDPModels.GridWorldState(1,1,false)=>MCTS.DPWStateNode{POMDPModels.GridWorldState,POMDPModels.GridWorldAction}(Dict(POMDPModels.GridWorldAction(:up)=>MCTS.DPWStateActionNode{POMDPModels.GridWorldState}(Dict(POMDPModels.GridWorldState(1,2,false)=>MCTS.StateActionStateNode(1,0.0)),1,0.0),POMDPModels.GridWorldAction(:down)=>MCTS.DPWStateActionNode{POMDPModels.GridWorldState}(Dict(POMDPModels.GridWorldState(1,1,false)=>MCTS.StateActionStateNode(1,0.0)),3,0.0),POMDPModels.GridWorldAction(:left)=>MCTS.DPWStateActionNode{POMDPModels.GridWorldState}(Dict(POMDPModels.GridWorldState(1,1,false)=>MCTS.StateActionStateNode(1,0.0)),10,0.0),POMDPModels.GridWorldAction(:right)=>MCTS.DPWStateActionNode{POMDPModels.GridWorldState}(Dict(POMDPModels.GridWorldState(2,1,false)=>MCTS.StateActionStateNode(1,0.0),POMDPModels.GridWorldState(1,2,false)=>MCTS.StateActionStateNode(1,0.0)),2,0.0)),17),POMDPModels.GridWorldState(2,1,false)=>MCTS.DPWStateNode{POMDPModels.GridWorldState,POMDPModels.GridWorldAction}(Dict{POMDPModels.GridWorldAction,MCTS.DPWStateActionNode{POMDPModels.GridWorldState}}(),1),POMDPModels.GridWorldState(1,2,false)=>MCTS.DPWStateNode{POMDPModels.GridWorldState,POMDPModels.GridWorldAction}(Dict(POMDPModels.GridWorldAction(:right)=>MCTS.DPWStateActionNode{POMDPModels.GridWorldState}(Dict(POMDPModels.GridWorldState(2,2,false)=>MCTS.StateActionStateNode(1,0.0)),1,0.0)),2)),POMDPToolbox.RandomPolicy(MersenneTwister(UInt32[0x00000000],Base.dSFMT.DSFMT_state(Int32[40050240,1073556905,73498706,1073647826,-1089444967,1072865807,-977052619,1072879190,-45002352,1072985674  …  16662824,1073697506,-1449805205,1073181468,-372400594,-464573168,1328968160,-848168375,382,0]),[1.82365,1.91036,1.16457,1.17733,1.27888,1.20348,1.0423,1.06827,1.36183,1.97322  …  1.63895,1.120 ...
