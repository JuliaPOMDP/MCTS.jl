# %%
using MCTS
using POMDPModels

function MCTS.node_tag(s::GridWorldState)
    if s.done
        return "done"
    end
    str = "[$(s.x),$(s.y)]"
    if s.bumped
        str = string(str, "(bumped)")
    end
    return str
end

MCTS.node_tag(a::GridWorldAction) = "[$(a.direction)]"
# Out:
# node_tag (generic function with 3 methods)

# %%
n_iter = 10000
depth = 100
ec = 10.0

solver = DPWSolver(n_iterations=n_iter, depth=depth, exploration_constant=ec)
mdp = GridWorld()

policy = solve(solver, mdp)

state = GridWorldState(9,2)

a = action(policy, state)
# Out:
# POMDPModels.GridWorldAction(:up)

# %%
TreeVisualizer(policy, state)
# Out:
# MCTS.TreeVisualizer{MCTS.DPWPolicy}(MCTS.DPWPolicy(MCTS.DPWSolver(100,10.0,10000,10.0,0.5,10.0,0.5,MersenneTwister(Base.dSFMT.DSFMT_state(Int32[-1802404000,1073172310,90897801,1073635968,-1826153880,1073305175,1374638006,1073714172,1778175414,1072756278  …  128505297,1073306387,-261886688,1073473091,-2023690343,2105651101,-55957404,-313025697,382,0]),[1.45687,1.89905,1.58358,1.97363,1.06011,1.01141,1.23959,1.96273,1.9493,1.16507  …  1.51828,1.9074,1.71655,1.7097,1.51027,1.40224,1.79322,1.0552,1.58473,1.74372],116,UInt32[0x00000000]),MCTS.RandomSolver(MersenneTwister(Base.dSFMT.DSFMT_state(Int32[-1802404000,1073172310,90897801,1073635968,-1826153880,1073305175,1374638006,1073714172,1778175414,1072756278  …  128505297,1073306387,-261886688,1073473091,-2023690343,2105651101,-55957404,-313025697,382,0]),[1.45687,1.89905,1.58358,1.97363,1.06011,1.01141,1.23959,1.96273,1.9493,1.16507  …  1.51828,1.9074,1.71655,1.7097,1.51027,1.40224,1.79322,1.0552,1.58473,1.74372],116,UInt32[0x00000000]))),POMDPModels.GridWorld(10,10,[POMDPModels.GridWorldState(4,3,false,false),POMDPModels.GridWorldState(4,6,false,false),POMDPModels.GridWorldState(9,3,false,false),POMDPModels.GridWorldState(8,8,false,false)],[-10.0,-5.0,10.0,3.0],-1.0,0.7,Set([POMDPModels.GridWorldState(8,8,false,false),POMDPModels.GridWorldState(9,3,false,false)]),0.95),Dict{POMDPs.State,MCTS.DPWStateNode}(POMDPModels.GridWorldState(10,2,true,false)=>MCTS.DPWStateNode(Dict{POMDPs.Action,MCTS.StateActionNode}(POMDPModels.GridWorldAction(:up)=>MCTS.StateActionNode(Dict{POMDPs.State,MCTS.StateActionStateNode}(POMDPModels.GridWorldState(10,3,false,false)=>MCTS.StateActionStateNode(10,-1.0),POMDPModels.GridWorldState(9,2,false,false)=>MCTS.StateActionStateNode(4,-1.0),POMDPModels.GridWorldState(10,1,false,false)=>MCTS.StateActionStateNode(4,-1.0)),18,5.832695138835679),POMDPModels.GridWorldAction(:down)=>MCTS.StateActionNode(Dict{POMDPs.State,MCTS.StateActionStateNode}(POMDPModels.GridWorldState(10,3,false,false)=>MCTS.StateActionStateNode(4,-1.0),POMDPModels.GridWorldState(9,2,false,false)=>MCTS.StateActionStateNode(3,-1.0),POMDPModels.GridWorldState(10,1,false,false)=>MCTS.StateActionStateNode(9,-1.0)),16,5.4678404174919),POMDPModels.GridWorldAction(:left)=>MCTS.StateActionNode(Dict{POMDPs.State,MCTS.StateActionStateNode}(POMDPModels.GridWorldState(10,3,false,false)=>MCTS.StateActionStateNode(2,-1.0),POMDPModels.GridWorldState(9,2,false,false)=>MCTS.StateActionStateNode(18,-1.0),POMDPModels.GridWorldState(10,1,false,false)=>MCTS.StateActionStateNode(9,-1.0)),29,6.7247385427609405),POMDPModels.GridWorldAction(:right)=>MCTS.StateActionNode(Dict{POMDPs.State,MCTS.StateActionStateNode}(POMDPModels.GridWorldState(10,2,true,false)=>MCTS.StateActionStateNode(15,-1.0)),15,4.9895380114930035)),78),POMDPModels.GridWorldState(7,2,false,false)=>MCTS.DPWStateNode(Dict{POMDPs.Action,MCTS.StateActionNode}(POMDPModels.GridWorldAction(:up)=>MCTS.StateActionNode(Dict{POMDPs.State,MCTS.StateActionStateNode}(POMDPModels.GridWorldState(6,2,false,false)=>MCTS.StateActionStateNode(17,0.0),POMDPModels.GridWorldState(7,3,false,false)=>MCTS.StateActionStateNode(158,0.0),POMDPModels.GridWorldState(7,1,false,false)=>MCTS.StateActionStateNode(18,0.0),POMDPModels.GridWorldState(8,2,false,false)=>MCTS.StateActionStateNode(22,0.0)),215,6.354630902276921),POMDPModels.GridWorldAction(:down)=>MCTS.StateActionNode(Dict{POMDPs.State,MCTS.StateActionStateNode}(POMDPModels.GridWorldState(6,2,false,false)=>MCTS.StateActionStateNode(3,0.0),POMDPModels.GridWorldState(7,3,false,false)=>MCTS.StateActionStateNode(3,0.0),POMDPModels.GridWorldState(7,1,false,false)=>MCTS.StateActionStateNode(24,0.0),POMDPModels.GridWorldState(8,2,false,false)=>MCTS.StateActionStateNode(3,0.0)),33,3.773266300205122),POMDPModels.GridWorldAction(:left)=>MCTS.StateActionNode(Dict{POMDPs.State,MCTS.StateActionStateNode}(POMDPModels.GridWorldState(6,2,false,false)=>MCTS.StateActionStateNode(5,0.0),POMDPModels.GridWorldState(7,3,false,false)=>MCTS.StateA ...
