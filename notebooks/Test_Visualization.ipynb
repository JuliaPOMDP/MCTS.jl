# %%
using MCTS
using POMDPModels

function MCTS.node_tag(s::GridWorldState)
    if s.done
        return "done"
    end
    str = "[$(s.x),$(s.y)]"
    if s.bumped
        str = string(str, "(bumped)")
    end
    return str
end

MCTS.node_tag(a::GridWorldAction) = "[$(a.direction)]"
# Out:
# node_tag (generic function with 3 methods)

# %%
n_iter = 10000
depth = 100
ec = 10.0

solver = DPWSolver(n_iterations=n_iter, depth=depth, exploration_constant=ec)
mdp = GridWorld()

policy = solve(solver, mdp)

state = GridWorldState(9,2)

a = action(policy, state)
# Out:
# POMDPModels.GridWorldAction(:up)

# %%
TreeVisualizer(policy, state)
# Out:
# MCTS.TreeVisualizer{MCTS.DPWPolicy{POMDPModels.GridWorldState,POMDPModels.GridWorldAction}}(MCTS.DPWPolicy{POMDPModels.GridWorldState,POMDPModels.GridWorldAction}(MCTS.DPWSolver(100,10.0,10000,10.0,0.5,10.0,0.5,MersenneTwister(Base.dSFMT.DSFMT_state(Int32[597555785,1072887710,49576765,1072705227,-1182913804,1072997933,-4548569,1073527018,1683273479,1072941303  …  -2116179897,1073278349,-378895785,1073290262,286644284,-184485889,-891600748,713520977,382,0]),[1.18545,1.01142,1.29057,1.79515,1.23656,1.16277,1.99939,1.59223,1.92727,1.04826  …  1.4163,1.56472,1.76993,1.27457,1.83833,1.43853,1.56266,1.75621,1.558,1.56936],232,UInt32[0x00000000]),POMDPToolbox.RandomSolver(MersenneTwister(Base.dSFMT.DSFMT_state(Int32[597555785,1072887710,49576765,1072705227,-1182913804,1072997933,-4548569,1073527018,1683273479,1072941303  …  -2116179897,1073278349,-378895785,1073290262,286644284,-184485889,-891600748,713520977,382,0]),[1.18545,1.01142,1.29057,1.79515,1.23656,1.16277,1.99939,1.59223,1.92727,1.04826  …  1.4163,1.56472,1.76993,1.27457,1.83833,1.43853,1.56266,1.75621,1.558,1.56936],232,UInt32[0x00000000])),MCTS.RandomActionGenerator(MersenneTwister(Base.dSFMT.DSFMT_state(Int32[597555785,1072887710,49576765,1072705227,-1182913804,1072997933,-4548569,1073527018,1683273479,1072941303  …  -2116179897,1073278349,-378895785,1073290262,286644284,-184485889,-891600748,713520977,382,0]),[1.18545,1.01142,1.29057,1.79515,1.23656,1.16277,1.99939,1.59223,1.92727,1.04826  …  1.4163,1.56472,1.76993,1.27457,1.83833,1.43853,1.56266,1.75621,1.558,1.56936],232,UInt32[0x00000000]),Nullable(POMDPModels.GridWorldActionSpace([POMDPModels.GridWorldAction(:up),POMDPModels.GridWorldAction(:down),POMDPModels.GridWorldAction(:left),POMDPModels.GridWorldAction(:right)])))),POMDPModels.GridWorld(10,10,[POMDPModels.GridWorldState(4,3,false,false),POMDPModels.GridWorldState(4,6,false,false),POMDPModels.GridWorldState(9,3,false,false),POMDPModels.GridWorldState(8,8,false,false)],[-10.0,-5.0,10.0,3.0],-1.0,0.7,Set([POMDPModels.GridWorldState(8,8,false,false),POMDPModels.GridWorldState(9,3,false,false)]),0.95),Dict(POMDPModels.GridWorldState(10,2,true,false)=>MCTS.DPWStateNode{POMDPModels.GridWorldState,POMDPModels.GridWorldAction}(Dict(POMDPModels.GridWorldAction(:up)=>MCTS.DPWStateActionNode{POMDPModels.GridWorldState}(Dict(POMDPModels.GridWorldState(10,3,false,false)=>MCTS.StateActionStateNode(4,-1.0),POMDPModels.GridWorldState(9,2,false,false)=>MCTS.StateActionStateNode(1,-1.0),POMDPModels.GridWorldState(10,1,false,false)=>MCTS.StateActionStateNode(2,-1.0)),7,4.023022872555123),POMDPModels.GridWorldAction(:down)=>MCTS.DPWStateActionNode{POMDPModels.GridWorldState}(Dict(POMDPModels.GridWorldState(10,3,false,false)=>MCTS.StateActionStateNode(2,-1.0),POMDPModels.GridWorldState(9,2,false,false)=>MCTS.StateActionStateNode(6,-1.0),POMDPModels.GridWorldState(10,1,false,false)=>MCTS.StateActionStateNode(10,-1.0)),18,5.548365222948693),POMDPModels.GridWorldAction(:left)=>MCTS.DPWStateActionNode{POMDPModels.GridWorldState}(Dict(POMDPModels.GridWorldState(10,3,false,false)=>MCTS.StateActionStateNode(1,-1.0),POMDPModels.GridWorldState(9,2,false,false)=>MCTS.StateActionStateNode(10,-1.0),POMDPModels.GridWorldState(10,1,false,false)=>MCTS.StateActionStateNode(1,-1.0)),12,6.374950994325806),POMDPModels.GridWorldAction(:right)=>MCTS.DPWStateActionNode{POMDPModels.GridWorldState}(Dict(POMDPModels.GridWorldState(10,2,true,false)=>MCTS.StateActionStateNode(95,-1.0)),95,-15.22611827785186)),133),POMDPModels.GridWorldState(7,2,false,false)=>MCTS.DPWStateNode{POMDPModels.GridWorldState,POMDPModels.GridWorldAction}(Dict(POMDPModels.GridWorldAction(:up)=>MCTS.DPWStateActionNode{POMDPModels.GridWorldState}(Dict(POMDPModels.GridWorldState(6,2,false,false)=>MCTS.StateActionStateNode(3,0.0),POMDPModels.GridWorldState(7,3,false,false)=>MCTS.StateActionStateNode(13,0.0),POMDPModels.GridWorldState(8,2,false,false)=>MCTS.StateActionStateNode(4,0.0),POMDPModels.GridWorldState(7,1,false,false)=>MCTS.St ...

# %%
n_iter = 10000
depth = 100
ec = 10.0

solver = AgUCTSolver(n_iterations=n_iter, depth=depth, exploration_constant=ec, enable_tree_vis=true)
mdp = GridWorld()

policy = solve(solver, mdp)

state = GridWorldState(9,2)

a = action(policy, state)
# Out:
# POMDPModels.GridWorldAction(:up)

# %%
TreeVisualizer(policy, state)
# Out:
# MCTS.TreeVisualizer{MCTS.AgUCTPolicy{POMDPModels.GridWorldState,POMDPModels.GridWorldAction}}(MCTS.AgUCTPolicy{POMDPModels.GridWorldState,POMDPModels.GridWorldAction}(MCTS.AgUCTSolver(10000,100,10.0,MCTS.NoAggregation(),MersenneTwister(Base.dSFMT.DSFMT_state(Int32[1549153314,1072821099,-110801354,1073182517,725066192,1073220882,171892940,1073065657,-109203642,1073725843  …  2088775271,1072970040,610026644,1072900741,1490704203,1628306725,1640046747,-693863615,382,0]),[1.12193,1.4666,1.50319,1.35516,1.98476,1.62882,1.901,1.99867,1.97486,1.71537  …  1.9198,1.36856,1.20693,1.88159,1.18144,1.652,1.57367,1.52494,1.26397,1.19788],271,UInt32[0x00000000]),POMDPToolbox.RandomSolver(MersenneTwister(Base.dSFMT.DSFMT_state(Int32[1549153314,1072821099,-110801354,1073182517,725066192,1073220882,171892940,1073065657,-109203642,1073725843  …  2088775271,1072970040,610026644,1072900741,1490704203,1628306725,1640046747,-693863615,382,0]),[1.12193,1.4666,1.50319,1.35516,1.98476,1.62882,1.901,1.99867,1.97486,1.71537  …  1.9198,1.36856,1.20693,1.88159,1.18144,1.652,1.57367,1.52494,1.26397,1.19788],271,UInt32[0x00000000])),true),POMDPModels.GridWorld(10,10,[POMDPModels.GridWorldState(4,3,false,false),POMDPModels.GridWorldState(4,6,false,false),POMDPModels.GridWorldState(9,3,false,false),POMDPModels.GridWorldState(8,8,false,false)],[-10.0,-5.0,10.0,3.0],-1.0,0.7,Set([POMDPModels.GridWorldState(8,8,false,false),POMDPModels.GridWorldState(9,3,false,false)]),0.95),POMDPToolbox.RandomPolicy(MersenneTwister(Base.dSFMT.DSFMT_state(Int32[1549153314,1072821099,-110801354,1073182517,725066192,1073220882,171892940,1073065657,-109203642,1073725843  …  2088775271,1072970040,610026644,1072900741,1490704203,1628306725,1640046747,-693863615,382,0]),[1.12193,1.4666,1.50319,1.35516,1.98476,1.62882,1.901,1.99867,1.97486,1.71537  …  1.9198,1.36856,1.20693,1.88159,1.18144,1.652,1.57367,1.52494,1.26397,1.19788],271,UInt32[0x00000000]),POMDPModels.GridWorld(10,10,[POMDPModels.GridWorldState(4,3,false,false),POMDPModels.GridWorldState(4,6,false,false),POMDPModels.GridWorldState(9,3,false,false),POMDPModels.GridWorldState(8,8,false,false)],[-10.0,-5.0,10.0,3.0],-1.0,0.7,Set([POMDPModels.GridWorldState(8,8,false,false),POMDPModels.GridWorldState(9,3,false,false)]),0.95),POMDPToolbox.VoidUpdater(),POMDPModels.GridWorldActionSpace([POMDPModels.GridWorldAction(:up),POMDPModels.GridWorldAction(:down),POMDPModels.GridWorldAction(:left),POMDPModels.GridWorldAction(:right)])),Dict{Any,MCTS.AgNode{POMDPModels.GridWorldAction}}(POMDPModels.GridWorldState(10,2,true,false)=>MCTS.AgNode{POMDPModels.GridWorldAction}(100,[MCTS.StateActionNode{POMDPModels.GridWorldAction}(POMDPModels.GridWorldAction(:up),5,5.693765741458709,Nullable(Set(Any[POMDPModels.GridWorldState(10,3,false,false),POMDPModels.GridWorldState(9,2,false,false),POMDPModels.GridWorldState(10,1,false,false)]))),MCTS.StateActionNode{POMDPModels.GridWorldAction}(POMDPModels.GridWorldAction(:down),4,3.5382244172649857,Nullable(Set(Any[POMDPModels.GridWorldState(10,3,false,false),POMDPModels.GridWorldState(9,2,false,false),POMDPModels.GridWorldState(10,1,false,false)]))),MCTS.StateActionNode{POMDPModels.GridWorldAction}(POMDPModels.GridWorldAction(:left),5,5.93668993107434,Nullable(Set(Any[POMDPModels.GridWorldState(10,3,false,false),POMDPModels.GridWorldState(9,2,false,false)]))),MCTS.StateActionNode{POMDPModels.GridWorldAction}(POMDPModels.GridWorldAction(:right),86,-15.63503861345118,Nullable(Set(Any[POMDPModels.GridWorldState(10,2,true,false)])))]),POMDPModels.GridWorldState(7,2,false,false)=>MCTS.AgNode{POMDPModels.GridWorldAction}(533,[MCTS.StateActionNode{POMDPModels.GridWorldAction}(POMDPModels.GridWorldAction(:up),72,4.1205683684175085,Nullable(Set(Any[POMDPModels.GridWorldState(6,2,false,false),POMDPModels.GridWorldState(7,3,false,false),POMDPModels.GridWorldState(8,2,false,false),POMDPModels.GridWorldState(7,1,false,false)]))),MCTS.StateActionNode{POMDPModels.GridWorldAction}(POMDPModels.GridWorldAction(:down),88,4.1 ...
