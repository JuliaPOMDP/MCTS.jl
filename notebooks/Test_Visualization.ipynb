# %%
using MCTS
using POMDPModels

function MCTS.node_tag(s::GridWorldState)
    if s.done
        return "done"
    end
    str = "[$(s.x),$(s.y)]"
    if s.bumped
        str = string(str, "(bumped)")
    end
    return str
end

MCTS.node_tag(a::GridWorldAction) = "[$(a.direction)]"
# Out:
# INFO: Recompiling stale cache file /home/zach/.julia/lib/v0.5/MCTS.ji for module MCTS.

# %%
n_iter = 10000
depth = 100
ec = 10.0

solver = DPWSolver(n_iterations=n_iter, depth=depth, exploration_constant=ec)
mdp = GridWorld()

policy = solve(solver, mdp)

state = GridWorldState(9,2)

a = action(policy, state)
# Out:
# POMDPModels.GridWorldAction(:up)

# %%
TreeVisualizer(policy, state) # click on the node to expand it
# Note, this does not appear correctly on github... to see it, either
#     1. Go to https://nbviewer.jupyter.org/github/JuliaPOMDP/MCTS.jl/blob/master/notebooks/Test_Visualization.ipynb
#     OR
#     2. Run it on your local Machine
# Out:
# MCTS.TreeVisualizer{MCTS.DPWPolicy{POMDPModels.GridWorldState,POMDPModels.GridWorldAction}}(MCTS.DPWPolicy{POMDPModels.GridWorldState,POMDPModels.GridWorldAction}(MCTS.DPWSolver(100,10.0,10000,10.0,0.5,10.0,0.5,MersenneTwister(UInt32[0x00000000],Base.dSFMT.DSFMT_state(Int32[-955736858,1072882778,944086449,1072959649,-321092109,1073730118,1729140882,1072749994,1904333073,1072935318  …  -1094544646,1073017203,921210208,1073123498,1286915481,1792586055,98132575,1449012586,382,0]),[1.18075,1.25406,1.98884,1.05412,1.23086,1.13655,1.43832,1.14783,1.9617,1.34856  …  1.59243,1.5282,1.37886,1.8061,1.48235,1.97249,1.63848,1.93248,1.30895,1.41032],319),POMDPToolbox.RandomSolver(MersenneTwister(UInt32[0x00000000],Base.dSFMT.DSFMT_state(Int32[-955736858,1072882778,944086449,1072959649,-321092109,1073730118,1729140882,1072749994,1904333073,1072935318  …  -1094544646,1073017203,921210208,1073123498,1286915481,1792586055,98132575,1449012586,382,0]),[1.18075,1.25406,1.98884,1.05412,1.23086,1.13655,1.43832,1.14783,1.9617,1.34856  …  1.59243,1.5282,1.37886,1.8061,1.48235,1.97249,1.63848,1.93248,1.30895,1.41032],319)),MCTS.RandomActionGenerator(MersenneTwister(UInt32[0x00000000],Base.dSFMT.DSFMT_state(Int32[-955736858,1072882778,944086449,1072959649,-321092109,1073730118,1729140882,1072749994,1904333073,1072935318  …  -1094544646,1073017203,921210208,1073123498,1286915481,1792586055,98132575,1449012586,382,0]),[1.18075,1.25406,1.98884,1.05412,1.23086,1.13655,1.43832,1.14783,1.9617,1.34856  …  1.59243,1.5282,1.37886,1.8061,1.48235,1.97249,1.63848,1.93248,1.30895,1.41032],319),Nullable{POMDPs.AbstractSpace{T}}(POMDPModels.GridWorldActionSpace(POMDPModels.GridWorldAction[POMDPModels.GridWorldAction(:up),POMDPModels.GridWorldAction(:down),POMDPModels.GridWorldAction(:left),POMDPModels.GridWorldAction(:right)])))),POMDPModels.GridWorld(10,10,POMDPModels.GridWorldState[POMDPModels.GridWorldState(4,3,false,false),POMDPModels.GridWorldState(4,6,false,false),POMDPModels.GridWorldState(9,3,false,false),POMDPModels.GridWorldState(8,8,false,false)],[-10.0,-5.0,10.0,3.0],-1.0,0.7,Set(POMDPModels.GridWorldState[POMDPModels.GridWorldState(8,8,false,false),POMDPModels.GridWorldState(9,3,false,false)]),0.95,[0.0,0.0,0.0]),Dict(POMDPModels.GridWorldState(10,2,true,false)=>MCTS.DPWStateNode{POMDPModels.GridWorldState,POMDPModels.GridWorldAction}(Dict(POMDPModels.GridWorldAction(:up)=>MCTS.DPWStateActionNode{POMDPModels.GridWorldState}(Dict(POMDPModels.GridWorldState(10,3,false,false)=>MCTS.StateActionStateNode(1,-1.0)),1,-7.27414),POMDPModels.GridWorldAction(:down)=>MCTS.DPWStateActionNode{POMDPModels.GridWorldState}(Dict(POMDPModels.GridWorldState(10,3,false,false)=>MCTS.StateActionStateNode(1,-1.0),POMDPModels.GridWorldState(9,2,false,false)=>MCTS.StateActionStateNode(2,-1.0),POMDPModels.GridWorldState(10,1,false,false)=>MCTS.StateActionStateNode(6,-1.0)),9,2.94695),POMDPModels.GridWorldAction(:left)=>MCTS.DPWStateActionNode{POMDPModels.GridWorldState}(Dict(POMDPModels.GridWorldState(10,3,false,false)=>MCTS.StateActionStateNode(1,-1.0),POMDPModels.GridWorldState(9,2,false,false)=>MCTS.StateActionStateNode(3,-1.0)),4,6.65668),POMDPModels.GridWorldAction(:right)=>MCTS.DPWStateActionNode{POMDPModels.GridWorldState}(Dict(POMDPModels.GridWorldState(10,2,true,false)=>MCTS.StateActionStateNode(1,-1.0)),98,-16.1479)),113),POMDPModels.GridWorldState(7,2,false,false)=>MCTS.DPWStateNode{POMDPModels.GridWorldState,POMDPModels.GridWorldAction}(Dict(POMDPModels.GridWorldAction(:up)=>MCTS.DPWStateActionNode{POMDPModels.GridWorldState}(Dict(POMDPModels.GridWorldState(6,2,false,false)=>MCTS.StateActionStateNode(6,0.0),POMDPModels.GridWorldState(7,3,false,false)=>MCTS.StateActionStateNode(22,0.0),POMDPModels.GridWorldState(8,2,false,false)=>MCTS.StateActionStateNode(5,0.0),POMDPModels.GridWorldState(7,1,false,false)=>MCTS.StateActionStateNode(8,0.0)),41,3.15838),POMDPModels.GridWorldAction(:down)=>MCTS.DPWStateActionNode{POMDPModels.GridWorldState}(Dict(POMDPModels.GridWorldState( ...
