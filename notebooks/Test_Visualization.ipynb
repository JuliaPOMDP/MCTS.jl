# %%
using MCTS
using POMDPModels

function MCTS.node_tag(s::GridWorldState)
    if s.done
        return "done"
    end
    str = "[$(s.x),$(s.y)]"
    if s.bumped
        str = string(str, "(bumped)")
    end
    return str
end

MCTS.node_tag(a::GridWorldAction) = "[$(a.direction)]"
# Out:
# node_tag (generic function with 3 methods)

# %%
n_iter = 10000
depth = 100
ec = 10.0

solver = DPWSolver(n_iterations=n_iter, depth=depth, exploration_constant=ec)
mdp = GridWorld()

policy = solve(solver, mdp)

state = GridWorldState(9,2)

a = action(policy, state)
# Out:
# POMDPModels.GridWorldAction(:up)

# %%
TreeVisualizer(policy, state) # click on the node to expand it
# Note, this does not appear correctly on github... to see it, either
#     1. Go to https://nbviewer.jupyter.org/github/JuliaPOMDP/MCTS.jl/blob/master/notebooks/Test_Visualization.ipynb
#     OR
#     2. Run it on your local Machine
# Out:
# MCTS.TreeVisualizer{MCTS.DPWPolicy{POMDPModels.GridWorldState,POMDPModels.GridWorldAction}}(MCTS.DPWPolicy{POMDPModels.GridWorldState,POMDPModels.GridWorldAction}(MCTS.DPWSolver(100,10.0,10000,10.0,0.5,10.0,0.5,MersenneTwister(Base.dSFMT.DSFMT_state(Int32[181291323,1073206771,1688439402,1073738222,-950254569,1073390650,540825415,1073088338,-567178636,1072974032  …  43908683,1072931444,-1752889472,1073527334,-413658851,1355163727,-732802532,-426254118,382,0]),[1.48973,1.99657,1.6651,1.37679,1.26778,1.68151,1.53012,1.16946,1.11633,1.6538  …  1.56118,1.22675,1.76645,1.72708,1.17671,1.4023,1.96742,1.43356,1.22716,1.79545],215,UInt32[0x00000000]),POMDPToolbox.RandomSolver(MersenneTwister(Base.dSFMT.DSFMT_state(Int32[181291323,1073206771,1688439402,1073738222,-950254569,1073390650,540825415,1073088338,-567178636,1072974032  …  43908683,1072931444,-1752889472,1073527334,-413658851,1355163727,-732802532,-426254118,382,0]),[1.48973,1.99657,1.6651,1.37679,1.26778,1.68151,1.53012,1.16946,1.11633,1.6538  …  1.56118,1.22675,1.76645,1.72708,1.17671,1.4023,1.96742,1.43356,1.22716,1.79545],215,UInt32[0x00000000])),MCTS.RandomActionGenerator(MersenneTwister(Base.dSFMT.DSFMT_state(Int32[181291323,1073206771,1688439402,1073738222,-950254569,1073390650,540825415,1073088338,-567178636,1072974032  …  43908683,1072931444,-1752889472,1073527334,-413658851,1355163727,-732802532,-426254118,382,0]),[1.48973,1.99657,1.6651,1.37679,1.26778,1.68151,1.53012,1.16946,1.11633,1.6538  …  1.56118,1.22675,1.76645,1.72708,1.17671,1.4023,1.96742,1.43356,1.22716,1.79545],215,UInt32[0x00000000]),Nullable(POMDPModels.GridWorldActionSpace([POMDPModels.GridWorldAction(:up),POMDPModels.GridWorldAction(:down),POMDPModels.GridWorldAction(:left),POMDPModels.GridWorldAction(:right)])))),POMDPModels.GridWorld(10,10,[POMDPModels.GridWorldState(4,3,false,false),POMDPModels.GridWorldState(4,6,false,false),POMDPModels.GridWorldState(9,3,false,false),POMDPModels.GridWorldState(8,8,false,false)],[-10.0,-5.0,10.0,3.0],-1.0,0.7,Set([POMDPModels.GridWorldState(8,8,false,false),POMDPModels.GridWorldState(9,3,false,false)]),0.95,[0.0,0.0,0.0]),Dict(POMDPModels.GridWorldState(10,2,true,false)=>MCTS.DPWStateNode{POMDPModels.GridWorldState,POMDPModels.GridWorldAction}(Dict(POMDPModels.GridWorldAction(:up)=>MCTS.DPWStateActionNode{POMDPModels.GridWorldState}(Dict(POMDPModels.GridWorldState(10,3,false,false)=>MCTS.StateActionStateNode(16,-1.0),POMDPModels.GridWorldState(9,2,false,false)=>MCTS.StateActionStateNode(6,-1.0),POMDPModels.GridWorldState(10,1,false,false)=>MCTS.StateActionStateNode(6,-1.0)),28,6.308313024513079),POMDPModels.GridWorldAction(:down)=>MCTS.DPWStateActionNode{POMDPModels.GridWorldState}(Dict(POMDPModels.GridWorldState(10,3,false,false)=>MCTS.StateActionStateNode(6,-1.0),POMDPModels.GridWorldState(9,2,false,false)=>MCTS.StateActionStateNode(1,-1.0),POMDPModels.GridWorldState(10,1,false,false)=>MCTS.StateActionStateNode(9,-1.0)),16,4.744608947424533),POMDPModels.GridWorldAction(:left)=>MCTS.DPWStateActionNode{POMDPModels.GridWorldState}(Dict(POMDPModels.GridWorldState(10,3,false,false)=>MCTS.StateActionStateNode(5,-1.0),POMDPModels.GridWorldState(9,2,false,false)=>MCTS.StateActionStateNode(26,-1.0),POMDPModels.GridWorldState(10,1,false,false)=>MCTS.StateActionStateNode(4,-1.0)),35,6.844593272948961),POMDPModels.GridWorldAction(:right)=>MCTS.DPWStateActionNode{POMDPModels.GridWorldState}(Dict(POMDPModels.GridWorldState(10,2,true,false)=>MCTS.StateActionStateNode(1,-1.0)),3,-4.866200742066106)),83),POMDPModels.GridWorldState(7,2,false,false)=>MCTS.DPWStateNode{POMDPModels.GridWorldState,POMDPModels.GridWorldAction}(Dict(POMDPModels.GridWorldAction(:up)=>MCTS.DPWStateActionNode{POMDPModels.GridWorldState}(Dict(POMDPModels.GridWorldState(7,3,false,false)=>MCTS.StateActionStateNode(1,0.0)),43,0.0),POMDPModels.GridWorldAction(:down)=>MCTS.DPWStateActionNode{POMDPModels.GridWorldState}(Dict(POMDPModels.GridWorldState(6,2,false,false)=>MCTS.StateActionStateNode(2,0.0),POMDPModels ...

# %%
n_iter = 10000
depth = 100
ec = 10.0

solver = AgUCTSolver(n_iterations=n_iter, depth=depth, exploration_constant=ec, enable_tree_vis=true)
mdp = GridWorld()

policy = solve(solver, mdp)

state = GridWorldState(9,2)

a = action(policy, state)
# Out:
# POMDPModels.GridWorldAction(:up)

# %%
TreeVisualizer(policy, state)
# Out:
# MCTS.TreeVisualizer{MCTS.AgUCTPolicy{POMDPModels.GridWorldState,POMDPModels.GridWorldAction}}(MCTS.AgUCTPolicy{POMDPModels.GridWorldState,POMDPModels.GridWorldAction}(MCTS.AgUCTSolver(10000,100,10.0,MCTS.NoAggregation(),MersenneTwister(Base.dSFMT.DSFMT_state(Int32[1350737586,1073633312,1838381773,1073300333,-646862043,1072754601,-2661059,1073097969,-1941021394,1073246083  …  2035242089,1072813368,191600154,1073616142,911210845,-2094462821,-1775744261,-178279094,382,0]),[1.89652,1.57896,1.05851,1.38597,1.52723,1.5517,1.40408,1.20015,1.86541,1.25702  …  1.08435,1.74632,1.2278,1.28201,1.29563,1.98849,1.31015,1.24097,1.11456,1.88014],199,UInt32[0x00000000]),POMDPToolbox.RandomSolver(MersenneTwister(Base.dSFMT.DSFMT_state(Int32[1350737586,1073633312,1838381773,1073300333,-646862043,1072754601,-2661059,1073097969,-1941021394,1073246083  …  2035242089,1072813368,191600154,1073616142,911210845,-2094462821,-1775744261,-178279094,382,0]),[1.89652,1.57896,1.05851,1.38597,1.52723,1.5517,1.40408,1.20015,1.86541,1.25702  …  1.08435,1.74632,1.2278,1.28201,1.29563,1.98849,1.31015,1.24097,1.11456,1.88014],199,UInt32[0x00000000])),true),POMDPModels.GridWorld(10,10,[POMDPModels.GridWorldState(4,3,false,false),POMDPModels.GridWorldState(4,6,false,false),POMDPModels.GridWorldState(9,3,false,false),POMDPModels.GridWorldState(8,8,false,false)],[-10.0,-5.0,10.0,3.0],-1.0,0.7,Set([POMDPModels.GridWorldState(8,8,false,false),POMDPModels.GridWorldState(9,3,false,false)]),0.95,[0.0,0.0,0.0]),POMDPToolbox.RandomPolicy(MersenneTwister(Base.dSFMT.DSFMT_state(Int32[1350737586,1073633312,1838381773,1073300333,-646862043,1072754601,-2661059,1073097969,-1941021394,1073246083  …  2035242089,1072813368,191600154,1073616142,911210845,-2094462821,-1775744261,-178279094,382,0]),[1.89652,1.57896,1.05851,1.38597,1.52723,1.5517,1.40408,1.20015,1.86541,1.25702  …  1.08435,1.74632,1.2278,1.28201,1.29563,1.98849,1.31015,1.24097,1.11456,1.88014],199,UInt32[0x00000000]),POMDPModels.GridWorld(10,10,[POMDPModels.GridWorldState(4,3,false,false),POMDPModels.GridWorldState(4,6,false,false),POMDPModels.GridWorldState(9,3,false,false),POMDPModels.GridWorldState(8,8,false,false)],[-10.0,-5.0,10.0,3.0],-1.0,0.7,Set([POMDPModels.GridWorldState(8,8,false,false),POMDPModels.GridWorldState(9,3,false,false)]),0.95,[0.0,0.0,0.0]),POMDPToolbox.VoidUpdater(),POMDPModels.GridWorldActionSpace([POMDPModels.GridWorldAction(:up),POMDPModels.GridWorldAction(:down),POMDPModels.GridWorldAction(:left),POMDPModels.GridWorldAction(:right)])),Dict{Any,MCTS.AgNode{POMDPModels.GridWorldAction}}(POMDPModels.GridWorldState(10,2,true,false)=>MCTS.AgNode{POMDPModels.GridWorldAction}(141,[MCTS.StateActionNode{POMDPModels.GridWorldAction}(POMDPModels.GridWorldAction(:up),14,4.662594197719437,Nullable(Set(Any[POMDPModels.GridWorldState(10,3,false,false),POMDPModels.GridWorldState(9,2,false,false),POMDPModels.GridWorldState(10,1,false,false)]))),MCTS.StateActionNode{POMDPModels.GridWorldAction}(POMDPModels.GridWorldAction(:down),8,3.8155183014343317,Nullable(Set(Any[POMDPModels.GridWorldState(10,3,false,false),POMDPModels.GridWorldState(10,1,false,false)]))),MCTS.StateActionNode{POMDPModels.GridWorldAction}(POMDPModels.GridWorldAction(:left),21,6.560640689248319,Nullable(Set(Any[POMDPModels.GridWorldState(10,3,false,false),POMDPModels.GridWorldState(9,2,false,false),POMDPModels.GridWorldState(10,1,false,false)]))),MCTS.StateActionNode{POMDPModels.GridWorldAction}(POMDPModels.GridWorldAction(:right),98,-16.14788626947511,Nullable(Set(Any[POMDPModels.GridWorldState(10,2,true,false)])))]),POMDPModels.GridWorldState(7,2,false,false)=>MCTS.AgNode{POMDPModels.GridWorldAction}(364,[MCTS.StateActionNode{POMDPModels.GridWorldAction}(POMDPModels.GridWorldAction(:up),11,-3.625998682774439,Nullable(Set(Any[POMDPModels.GridWorldState(7,3,false,false),POMDPModels.GridWorldState(7,1,false,false)]))),MCTS.StateActionNode{POMDPModels.GridWorldAction}(POMDPModels.GridWorldAction(:down),22,1.8391877902539062,Nullable(Set(Any[POMDP ...
