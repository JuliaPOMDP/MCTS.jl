# %%
using MCTS
using POMDPModels

function MCTS.node_tag(s::GridWorldState)
    if s.done
        return "done"
    end
    str = "[$(s.x),$(s.y)]"
    if s.bumped
        str = string(str, "(bumped)")
    end
    return str
end

MCTS.node_tag(a::GridWorldAction) = "[$(a.direction)]"
# Out:
# node_tag (generic function with 3 methods)

# %%
n_iter = 10000
depth = 100
ec = 10.0

solver = DPWSolver(n_iterations=n_iter, depth=depth, exploration_constant=ec)
mdp = GridWorld()

policy = solve(solver, mdp)

state = GridWorldState(9,2)

a = action(policy, state)
# Out:
# POMDPModels.GridWorldAction(:up)

# %%
TreeVisualizer(policy, state)
# Out:
# MCTS.TreeVisualizer{MCTS.DPWPolicy}(MCTS.DPWPolicy(MCTS.DPWSolver(100,10.0,10000,10.0,0.5,10.0,0.5,MersenneTwister(Base.dSFMT.DSFMT_state(Int32[-1802404000,1073172310,90897801,1073635968,-1826153880,1073305175,1374638006,1073714172,1778175414,1072756278  …  128505297,1073306387,-261886688,1073473091,-2023690343,2105651101,-55957404,-313025697,382,0]),[1.45687,1.89905,1.58358,1.97363,1.06011,1.01141,1.23959,1.96273,1.9493,1.16507  …  1.51828,1.9074,1.71655,1.7097,1.51027,1.40224,1.79322,1.0552,1.58473,1.74372],116,UInt32[0x00000000]),MCTS.RandomSolver(MersenneTwister(Base.dSFMT.DSFMT_state(Int32[-1802404000,1073172310,90897801,1073635968,-1826153880,1073305175,1374638006,1073714172,1778175414,1072756278  …  128505297,1073306387,-261886688,1073473091,-2023690343,2105651101,-55957404,-313025697,382,0]),[1.45687,1.89905,1.58358,1.97363,1.06011,1.01141,1.23959,1.96273,1.9493,1.16507  …  1.51828,1.9074,1.71655,1.7097,1.51027,1.40224,1.79322,1.0552,1.58473,1.74372],116,UInt32[0x00000000])),MCTS.RandomActionGenerator(MersenneTwister(Base.dSFMT.DSFMT_state(Int32[-1802404000,1073172310,90897801,1073635968,-1826153880,1073305175,1374638006,1073714172,1778175414,1072756278  …  128505297,1073306387,-261886688,1073473091,-2023690343,2105651101,-55957404,-313025697,382,0]),[1.45687,1.89905,1.58358,1.97363,1.06011,1.01141,1.23959,1.96273,1.9493,1.16507  …  1.51828,1.9074,1.71655,1.7097,1.51027,1.40224,1.79322,1.0552,1.58473,1.74372],116,UInt32[0x00000000]),POMDPModels.ActionSpace([POMDPModels.GridWorldAction(:up),POMDPModels.GridWorldAction(:down),POMDPModels.GridWorldAction(:left),POMDPModels.GridWorldAction(:right)]))),POMDPModels.GridWorld(10,10,[POMDPModels.GridWorldState(4,3,false,false),POMDPModels.GridWorldState(4,6,false,false),POMDPModels.GridWorldState(9,3,false,false),POMDPModels.GridWorldState(8,8,false,false)],[-10.0,-5.0,10.0,3.0],-1.0,0.7,Set([POMDPModels.GridWorldState(8,8,false,false),POMDPModels.GridWorldState(9,3,false,false)]),0.95),Dict{POMDPs.State,MCTS.DPWStateNode}(POMDPModels.GridWorldState(10,2,true,false)=>MCTS.DPWStateNode(Dict{POMDPs.Action,MCTS.DPWStateActionNode}(POMDPModels.GridWorldAction(:up)=>MCTS.DPWStateActionNode(Dict{POMDPs.State,MCTS.StateActionStateNode}(POMDPModels.GridWorldState(10,3,false,false)=>MCTS.StateActionStateNode(10,-1.0),POMDPModels.GridWorldState(9,2,false,false)=>MCTS.StateActionStateNode(4,-1.0),POMDPModels.GridWorldState(10,1,false,false)=>MCTS.StateActionStateNode(4,-1.0)),18,5.832695138835679),POMDPModels.GridWorldAction(:down)=>MCTS.DPWStateActionNode(Dict{POMDPs.State,MCTS.StateActionStateNode}(POMDPModels.GridWorldState(10,3,false,false)=>MCTS.StateActionStateNode(4,-1.0),POMDPModels.GridWorldState(9,2,false,false)=>MCTS.StateActionStateNode(3,-1.0),POMDPModels.GridWorldState(10,1,false,false)=>MCTS.StateActionStateNode(9,-1.0)),16,5.4678404174919),POMDPModels.GridWorldAction(:left)=>MCTS.DPWStateActionNode(Dict{POMDPs.State,MCTS.StateActionStateNode}(POMDPModels.GridWorldState(10,3,false,false)=>MCTS.StateActionStateNode(2,-1.0),POMDPModels.GridWorldState(9,2,false,false)=>MCTS.StateActionStateNode(18,-1.0),POMDPModels.GridWorldState(10,1,false,false)=>MCTS.StateActionStateNode(9,-1.0)),29,6.7247385427609405),POMDPModels.GridWorldAction(:right)=>MCTS.DPWStateActionNode(Dict{POMDPs.State,MCTS.StateActionStateNode}(POMDPModels.GridWorldState(10,2,true,false)=>MCTS.StateActionStateNode(15,-1.0)),15,4.9895380114930035)),78),POMDPModels.GridWorldState(7,2,false,false)=>MCTS.DPWStateNode(Dict{POMDPs.Action,MCTS.DPWStateActionNode}(POMDPModels.GridWorldAction(:up)=>MCTS.DPWStateActionNode(Dict{POMDPs.State,MCTS.StateActionStateNode}(POMDPModels.GridWorldState(6,2,false,false)=>MCTS.StateActionStateNode(17,0.0),POMDPModels.GridWorldState(7,3,false,false)=>MCTS.StateActionStateNode(158,0.0),POMDPModels.GridWorldState(7,1,false,false)=>MCTS.StateActionStateNode(18,0.0),POMDPModels.GridWorldState(8,2,false,false)=>MCTS.StateActionStateNode(22,0.0)),215,6.354630902276921),POMDPModels.GridWor ...

# %%
n_iter = 10000
depth = 100
ec = 10.0

solver = AgUCTSolver(n_iterations=n_iter, depth=depth, exploration_constant=ec, enable_tree_vis=true)
mdp = GridWorld()

policy = solve(solver, mdp)

state = GridWorldState(9,2)

a = action(policy, state)
# Out:
# POMDPModels.GridWorldAction(:up)

# %%
TreeVisualizer(policy, state)
# Out:
# MCTS.TreeVisualizer{MCTS.AgUCTPolicy}(MCTS.AgUCTPolicy(MCTS.AgUCTSolver(10000,100,10.0,MCTS.NoAggregation(),MersenneTwister(Base.dSFMT.DSFMT_state(Int32[1549153314,1072821099,-110801354,1073182517,725066192,1073220882,171892940,1073065657,-109203642,1073725843  …  2088775271,1072970040,610026644,1072900741,1490704203,1628306725,1640046747,-693863615,382,82]),[1.12193,1.4666,1.50319,1.35516,1.98476,1.62882,1.901,1.99867,1.97486,1.71537  …  1.9198,1.36856,1.20693,1.88159,1.18144,1.652,1.57367,1.52494,1.26397,1.19788],271,UInt32[0x00000000]),MCTS.RandomSolver(MersenneTwister(Base.dSFMT.DSFMT_state(Int32[1549153314,1072821099,-110801354,1073182517,725066192,1073220882,171892940,1073065657,-109203642,1073725843  …  2088775271,1072970040,610026644,1072900741,1490704203,1628306725,1640046747,-693863615,382,82]),[1.12193,1.4666,1.50319,1.35516,1.98476,1.62882,1.901,1.99867,1.97486,1.71537  …  1.9198,1.36856,1.20693,1.88159,1.18144,1.652,1.57367,1.52494,1.26397,1.19788],271,UInt32[0x00000000])),true),POMDPModels.GridWorld(10,10,[POMDPModels.GridWorldState(4,3,false,false),POMDPModels.GridWorldState(4,6,false,false),POMDPModels.GridWorldState(9,3,false,false),POMDPModels.GridWorldState(8,8,false,false)],[-10.0,-5.0,10.0,3.0],-1.0,0.7,Set([POMDPModels.GridWorldState(8,8,false,false),POMDPModels.GridWorldState(9,3,false,false)]),0.95),MCTS.RandomPolicy(POMDPModels.GridWorld(10,10,[POMDPModels.GridWorldState(4,3,false,false),POMDPModels.GridWorldState(4,6,false,false),POMDPModels.GridWorldState(9,3,false,false),POMDPModels.GridWorldState(8,8,false,false)],[-10.0,-5.0,10.0,3.0],-1.0,0.7,Set([POMDPModels.GridWorldState(8,8,false,false),POMDPModels.GridWorldState(9,3,false,false)]),0.95),MersenneTwister(Base.dSFMT.DSFMT_state(Int32[1549153314,1072821099,-110801354,1073182517,725066192,1073220882,171892940,1073065657,-109203642,1073725843  …  2088775271,1072970040,610026644,1072900741,1490704203,1628306725,1640046747,-693863615,382,82]),[1.12193,1.4666,1.50319,1.35516,1.98476,1.62882,1.901,1.99867,1.97486,1.71537  …  1.9198,1.36856,1.20693,1.88159,1.18144,1.652,1.57367,1.52494,1.26397,1.19788],271,UInt32[0x00000000]),POMDPModels.ActionSpace([POMDPModels.GridWorldAction(:up),POMDPModels.GridWorldAction(:down),POMDPModels.GridWorldAction(:left),POMDPModels.GridWorldAction(:right)])),Dict{Any,MCTS.AgNode}(POMDPModels.GridWorldState(10,2,true,false)=>MCTS.AgNode(100,[MCTS.StateActionNode(POMDPModels.GridWorldAction(:up),5,5.693765741458709,Set(Any[POMDPModels.GridWorldState(10,3,false,false),POMDPModels.GridWorldState(9,2,false,false),POMDPModels.GridWorldState(10,1,false,false)])),MCTS.StateActionNode(POMDPModels.GridWorldAction(:down),4,3.5382244172649857,Set(Any[POMDPModels.GridWorldState(10,3,false,false),POMDPModels.GridWorldState(9,2,false,false),POMDPModels.GridWorldState(10,1,false,false)])),MCTS.StateActionNode(POMDPModels.GridWorldAction(:left),5,5.93668993107434,Set(Any[POMDPModels.GridWorldState(10,3,false,false),POMDPModels.GridWorldState(9,2,false,false)])),MCTS.StateActionNode(POMDPModels.GridWorldAction(:right),86,-15.63503861345118,Set(Any[POMDPModels.GridWorldState(10,2,true,false)]))]),POMDPModels.GridWorldState(7,2,false,false)=>MCTS.AgNode(533,[MCTS.StateActionNode(POMDPModels.GridWorldAction(:up),72,4.1205683684175085,Set(Any[POMDPModels.GridWorldState(6,2,false,false),POMDPModels.GridWorldState(7,3,false,false),POMDPModels.GridWorldState(8,2,false,false),POMDPModels.GridWorldState(7,1,false,false)])),MCTS.StateActionNode(POMDPModels.GridWorldAction(:down),88,4.171952575016194,Set(Any[POMDPModels.GridWorldState(6,2,false,false),POMDPModels.GridWorldState(7,3,false,false),POMDPModels.GridWorldState(7,1,false,false),POMDPModels.GridWorldState(8,2,false,false)])),MCTS.StateActionNode(POMDPModels.GridWorldAction(:left),42,3.2853067697940688,Set(Any[POMDPModels.GridWorldState(6,2,false,false),POMDPModels.GridWorldState(7,3,false,false),POMDPModels.GridWorldState(7,1,false,false),POMDPModels.GridWorldState(8,2,false,false)])),MCTS. ...
